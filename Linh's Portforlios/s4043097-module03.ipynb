# %% [markdown]
# <center>
#
# # COSC3056 Programming Studio 1 Portfolio
# # Module 3: Building User Experiences and Interfaces
#
# </center>

# %% [markdown]
# This portfolio is created by
#
# | Name | Trần Hoàng Linh |
# |---|---|
# | Student Id | S4043097 |
# | Semester | Semester 3 2023 |

# %% [markdown]
# ### Declaration and Statement of Authorship
#
# When you submit your work electronically for studio components, you must agree to the [RMIT assessment declaration](https://www.rmit.edu.au/students/my-course/assessment-results/assessment) below.
#
# 1. I/we have not impersonated, or allowed myself to be impersonated by, any person for the purposes of this assessment.
# 2. This assessment is my/our original work and no part of it has been copied from any other source except where due acknowledgement
# is made.
# 3. No part of this assessment has been written for me/us by any other person except where such collaboration has been authorised
# by the lecturer/teacher concerned.
# 4. Where this work is being submitted for individual assessment, I declare that it is my original work and that no part has been contributed
# by, produced by or in conjunction with another student.
# 5. I/we give permission for my assessment response to be reproduced, communicated compared and archived for the purposes
# of detecting plagiarism.
# 6. I/we give permission for a copy of my assessment to be retained by the university for review and comparison, including review by external examiners.
# 7. I/we understand that:
#     - Plagiarism is the presentation of the work, idea or creation of another person as though it is your own. It is a form of cheating and is a very serious academic offence that may lead to exclusion from the University. Plagiarised material can be drawn from, and presented in, written, graphic and visual form, including electronic data and oral presentations. Plagiarism occurs when the origin of the material used is not appropriately cited.
#     - Plagiarism includes the act of assisting or allowing another person to plagiarise or to copy my work.
#
#
# I/we agree and acknowledge that:
# 1. I/we have read and understood the Declaration and Statement of Authorship above.
# 2. If I/we do not agree to the Declaration and Statement of Authorship in this context and a signature is not included below, the assessment outcome is not valid for assessment purposes and will not be included in my final result for this course.
#
# Visit the student essentials Academic Integrity page for more information on [academic integrity at RMIT](https://www.rmit.edu.au/students/my-course/assessment-results/academic-integrity), including your responsibilities,
# breaches and penalties for academic misconduct.
#
#
# ### Student Signature
# "_I/we declare that I/we have read and understood the above Declaration and Statement of Authorship._"
#
# You must write your full name and student ID in the table in the markdown cell at the top of this portfolio.<br>
# **Failure to do so may result in a grade penalty or a grade of zero.**

# %% [markdown]
# <style>
# blockquote {
#   border: 3px dashed #00DCB4;
#   padding: 10px;
# }
# </style>
#
# > ## Instructions & Information
# > This notebook template has been provided to get you started on your portolfio. It is also structured for the automated marking tool SageGrader.
# > Therefore, we require that you use and edit the notebook correctly.
# >
# > ### How to use this Notebook for your Portfolio
# > To use your notebook, we kindly ask that:
# > 1. Place your answer to the question in the **existing** answer block, by double-clicking on the block you wish to edit.
# > 1. You **must not** delete any existing cells in this notebook and you **must not** modify any existing cell tags. If you accidentally delete a cell, you will need to ``undo'' the change, such using the  "Edit → Undo" VSCode menu option.
# > 1. In general, answer cells will have denoted placeholder content with dummy values, such as comments like *`my answer'*.
# > 1. You **must not** change any text in an existing cell that is **outside** of block to place your answers.
# > 1. To add images to this notebook you **must embedd the image** into the notebook. To do this:
# >     1. Find the image on your computer (Windows: File Explorer, Mac: Finder). Note the image can't have spaces in the filename
# >     1. "Copy" the image (Right-click on the image → Copy)
# >     1. "Paste" the image into the cell below (Double click to edit the cell → Right-click → Paste)
# >     1. If this is done correctly, you should see something of the form ``![image-name.png](attachment:image-name.png)``
# >     1. Please make sure to press the tick '✔️' on the cell containing the image to ensure the attachment is added
# > 1. Please see Canvas for additional assessment instructions.
# >
# > ### How to use Markdown syntax
# > This notebook uses the markdown syntax for formatting. For help on using Markdown, IBM has a good [Markdown Cheat-sheet](https://www.ibm.com/docs/en/watson-studio-local/1.2.3?topic=notebooks-markdown-jupyter-cheatsheet).

# %% [markdown]
# <style>
# h2 {
#    text-align: center;
# }
# hr {
#   border: none;
#   border-top: 6px ridge #04cfc5;
# }
# </style>
# ___
#
# ## Studio Class 9: Scenarios and Storyboarding
#
# ### Preparation Activities

# %% [markdown]
# **Questions**

# %% [markdown]
# ### **Studio Class (SC) 9, Question 1:** <a id="q9a"></a>
#
# Why are Scenarios and Storyboards part of the User Centred Design process?

# %% [markdown]
# Scenarios and Storyboards are part of the User Centred Design process as they create a better solution and communicate the user experience in a human way

# %% [markdown]
# ### **Studio Class (SC) 9, Question 2:** <a id="q9b"></a>
#
# What the key benefits of Scenarios and Storyboards?

# %% [markdown]
# - To confirm that the design is viable and realistic
# - Providing fundamental types of interaction that is needed for the design
# - To find errors that might have in the the design
# - To find how the user flow when using the app
# - Avoid spending time re-do an already done task

# %% [markdown]
# ### **Studio Class (SC) 9, Question 3:** <a id="q9c"></a>
#
# What the three important elements for creating good quality scenarios?

# %% [markdown]
# - Should describe the different elements of the UX that u aim to build
# - Demonstrate how that experience meet the goals that u created
# - Describe how

# %% [markdown]
# ### **Studio Class (SC) 9, Question 4:** <a id="q9d"></a>
#
# How do storyboards relate to scenarios?

# %% [markdown]
# Scenarios help to create storyboards, most of the information u need to create a storyboard is all ready in scenarios. If u have a good scenarios then it is easier for you to create a storyboard

# %% [markdown]
# ### **Studio Class (SC) 9, Question 5:** <a id="q9e"></a>
#
# Provide the details of your prepared version of the Lynn Persona.

# %% [markdown]
# <b>Contribute</b>
# - Name: Lynn
# - Age: 28
# - Gender: Female
# - Status: Married
# - Occupation: Manager
# - Household: Lives with her husband, her two son Zach (14) and Justin (10)
#
# <b>Needs & Goals</b>
#
# - A way to monitor and organize her house
# - A way to give and assign different task to her sons for each week
#
# <b>Paint points</b>
# - Can't assign task for her kid when she not home
# - Can't catch up to the house situation in realtime
# - Have trouble with reward her kids
#
# <b>Skill & Experience</b>
# -  Familiar with tech-based applications
# -  Have access to the Internet all the time

# %% [markdown]
# ### Studio Class Work

# %% [markdown]
# **Questions**

# %% [markdown]
# ### **Studio Class (SC) 9, Question 6:** <a id="q9f"></a>
#
# Provide the image of your groups version of the Lynn Persona.

# %% [markdown]
# ![a752f2e9-7d97-4393-a217-94bfe57ebab6.png](attachment:a752f2e9-7d97-4393-a217-94bfe57ebab6.png)

# %% [markdown]
# ### **Studio Class (SC) 9, Question 7:** <a id="q9g"></a>
#
# Record your group's 3 Context Scenarios

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **Studio Class (SC) 9, Question 8:** <a id="q9h"></a>
#
# Provide the image of your individual storyboard

# %% [markdown]
# *My image*

# %% [markdown]
# <style>
# h2 {
#    text-align: center;
# }
# hr {
#   border: none;
#   border-top: 6px ridge #04cfc5;
# }
# </style>
# ___
#
# ## Studio Class 10: Paper Prototyping
#
# ### Preparation Activities

# %% [markdown]
# **Questions**

# %% [markdown]
# ### **Studio Class (SC) 10, Question 1:** <a id="q10a"></a>
#
# Why should we conduct paper prototyping as part of the User-Centred Design
# m process?

# %% [markdown]
# It is a fast to build, fast to change and easy to iterate. It is also cheap because it use cheap material, and take very little time. Paper prototyping is also very flexible. Users are also more honest with their feedback more then when u give them a pixel perfect product

# %% [markdown]
# ### **Studio Class (SC) 10, Question 2:** <a id="q10b"></a>
#
# How do the following elements of the User-Centred Design process help to infor the construction of a Paper Prototype?

# %% [markdown]
# | Element | Answer |
# |---|---|
# | Persona |The persona is need when we develop the scenario which later use to create the paper prototype|
# | Scenario (Context & Keypath) |

# %% [markdown]
# To pick the most important feature that the user want to have in the user interface |

# %% [markdown]
# ### **Studio Class (SC) 10, Question 3:** <a id="q10c"></a>
#
# What are the benefit(s) of testing a paper prototype with an end user?

# %% [markdown]
# Using paper prototype as a testing method will provide: <br> - Early user feedback: which help identify potential future issues and make necessary <br> - User engagement: it is better to show users a paper prototype then a perfect-pixel design, paper prototype let the user open up and give truthful feedback with minimum drawback

# %% [markdown]
# ### Studio Class Work

# %% [markdown]
# **Questions**

# %% [markdown]
# ### **Studio Class (SC) 10, Question 4:** <a id="q10d"></a>
#
# Provide a single image that shows your first screen with a description and mapping for the "ChoreTracker" App for which your group will create a prototype.

# %% [markdown]
# ![login.png](attachment:login.png)

# %% [markdown]
# ### **Studio Class (SC) 10, Question 5:** <a id="q10e"></a>
#
# Provide a single image that shows your second screen with a description and mapping for the "ChoreTracker" App for which your group will create a prototype.

# %% [markdown]
# After the login page to identify the user the user will come to a welcome screen where they have access to all the feature of the app.

# %% [markdown]
# ![task.png](attachment:task.png)

# %% [markdown]
# ### **Studio Class (SC) 10, Question 6:** <a id="q10f"></a>
#
# Provide a single image that shows your third screen with a description and mapping for the "ChoreTracker" App for which your group will create a prototype.

# %% [markdown]
# The main feature of this application is that users(admin) can give and assign task for each member within a group that create by the user, they can see when the task is give and also the finish time

# %% [markdown]
# ![task.png](attachment:task.png)

# %% [markdown]
# ### **Studio Class (SC) 10, Question 7:** <a id="q10g"></a>
#
# Your group's choice of navigation model & explanation.
# Document these choices with your explainations.

# %% [markdown]
# Our application want to go with <b>Hub and Spoke</b> navigation model, the reason for this mainly depend on the type of device users will use while using the app. With a mobile-platform application we want to label all of the the main feature on to the home screen of the user device, this will help users to navigate around the app easier and more consistency.

# %% [markdown]
# ### **Studio Class (SC) 10, Question 8:** <a id="q10h"></a>
#
# For each page, determine at least one Navigation Design Pattern that will be used on the page.
# Document these choices with your explainations.

# %% [markdown]
# <b>Page 1:Login Page</b>
#
# - Modal: the app will have an option for the user to denied login into the app but then they can't access all of the feature that include in the app. If the user decide to not login they will be linked to the About page where they get the rough information about all the feature that have in the app
#
# -
#
# <b>Page 2:Home Page</b>
#
# - Home Link: Home Link will be use to give the user a way to return back to the homepage asap, this can be consider like an escape hatch for the user
#
# - Pull to refresh: A quick way for users to keep up with the newest information without going through number of process
#
# - Notifications: This is where users will get notify with all the task that have been done, on progress, etc etc. It is the best method to keep up to date
#
# <b>Page 3: Task Manager</b>
# - Home Link: Home Link will be use to give the user a way to return back to the homepage asap, this can be consider like an escape hatch for the user
# - Card: Card will be used to divide each task, make it easier for the user to see

# %% [markdown]
# ### **Studio Class (SC) 10, Question 9:** <a id="q10i"></a>
#
# For each page, determine how at least one Page Layout Design Pattern will be applied on the page.
# Document these choices with your explainations.

# %% [markdown]
# All of our page will use center stage as our page layout design. Center stage is where all the element will alway display in the middle of the screen this help user to focus on their task and emphasize the content of the page

# %% [markdown]
# ### **Studio Class (SC) 10, Question 10:** <a id="q10j"></a>
#
# For each page, determine at least one Interaction Design Pattern that will be used on the page.
# Document these choices with your explainations.

# %% [markdown]
# *My Answer*

# %% [markdown]
# ### **Studio Class (SC) 10, Question 11:** <a id="q10k"></a>
#
# Provide screenshots of your group's entire paper prototype.

# %% [markdown]
# [*My image*](<img/Scanned Document 3.pdf>)

# %% [markdown]
# ### **Studio Class (SC) 10, Question 12:** <a id="q10l"></a>
#
# Provide screenshots of your individual contributions to your group's paper prototype

# %% [markdown]
# ![Screenshot 2024-01-14 at 18.07.15.png](<attachment:Screenshot 2024-01-14 at 18.07.15.png>)

# %% [markdown]
# ### **Studio Class (SC) 10, Question 13:** <a id="q10m"></a>
#
# Group Review:
#
# For the parts of the key path scenario where elements of the paper prototype were missing, create additional features as required.
#
# Provide the additional screenshots that include these features.

# %% [markdown]
# *My image*

# %% [markdown]
# <style>
# h2 {
#    text-align: center;
# }
# hr {
#   border: none;
#   border-top: 6px ridge #04cfc5;
# }
# </style>
# ___
#
#
# ## Studio Class 11: User Research & User Feedback Methods
#
# ### Preparation Activities

# %% [markdown]
# **Questions**

# %% [markdown]
# ### **Studio Class (SC) 11, Question 1:** <a id="q11a"></a>
#
# In Week 1, we completed an activity to construct a User Experience Map, which is one form of user research that is not included in Landscape of User Research Methods diagram.
#
# Annotate the diagram to place the User Experience Map on the diagram indicating where an experience map fits in the diagram.
#
# The annotation should include notes as to why you placed it where you did.

# %% [markdown]
# ![Frame 2.png](<attachment:Frame 2.png>)

# %% [markdown]
# ### **Studio Class (SC) 11, Question 2:** <a id="q11b"></a>
#
# Why is it useful to start writing a survey with expressing the 'report' or types of conclusions we would like to draw from the survey?

# %% [markdown]
# |Question |
# |---|
# | Why is it useful to start writing a survey with expressing the 'report' or types of conclusions we would like to draw from the survey? |
# |- Creating a report that includes the desired outcome and conclusions statements is beneficial for shaping our questions and answers. This ensures that we focus on inquiries relevant to our concerns and facilitates the ease of survey analysis. |
# | Why should the survey questions be unbiased? |
# |-  A successful survey is base on clear, honest responses from users. Comprehensible questions, employing a well-rounded set ensures comprehensive data coverage.|

# %% [markdown]
# ### **Studio Class (SC) 11, Question 3:** <a id="q11c"></a>
#
# Describe 3 different types of survey questions.

# %% [markdown]
# | Question Type | Answer |
# |---|---|
# | Multiple Choice | Let the user choose one or multiple option from a list |
# | Rating Questions | Let the user rate something using a linear scale, it can also show in a agree or disagree bar which user can interact with and give feedback to the product |
# | Ranking Questions| Let the user to rank a list of option base on their preferences |

# %% [markdown]
# ### **Studio Class (SC) 11, Question 4:** <a id="q11d"></a>
#
# Describe 3 common mistakes when writing survey questions.

# %% [markdown]
# | Mistake | Answer |
# |---|---|
# | Mistake 1 | - Asking about the Future, it is better for the users used to use/do rather then know what they will use and do |
# | *Mistake 2* | - Assume that everyone is the same to the other, each person will have different experience doing a certain task. And each will provide different data and feedback|
# | *Mistake 3* | - Used Industry's word related inside the survey, not everyone is change to have enough vocab about anything, it is better for u to use normal talking language to the user so that they can easily understand the question |

# %% [markdown]
# ### **Studio Class (SC) 11, Question 5:** <a id="q11e"></a>
#
# Why is it important to be careful about the people you survey?

# %% [markdown]
# Choosing the right group of people to survey will alway provide you with not only the amount of data that you receive but also the data's quality is also better if you choose the right survey target. But on the other side of the table, there will always be biased happen in a group of survey if given to the right person since they already know what is the better option to go with and thus don't provide enough info in the other part of the survey

# %% [markdown]
# ### **Studio Class (SC) 11, Question 6:** <a id="q11f"></a>
#
# When is it beneficial to use the following quantitative measures that can be computed from survey responses:

# %% [markdown]
# | Measure | Answer |
# |---|---|
# | Median | - An effective representation of the average or middle response is valuable as it remains robust against outlier values and performs well in dealing with skewed distributions. |
# | Mean | - Finding the average price, age, and satisfaction level is valuable as it provides a central tendency that encompasses outlier values, offering a comprehensive measure.  |
# | Mode | - Facilitate quick identification of the prevailing response and offer insights into trends or patterns based on user answers. |

# %% [markdown]
# ### **Studio Class (SC) 11, Question 7:** <a id="q11g"></a>
#
# What is the purpose of PIF?

# %% [markdown]
# PIF aims to provide survey participants with information regarding the survey's context and purpose. It outlines participants' rights during and after survey participation, communicates the data handling process, and serves as a consent form. Survey conductors must seek the participant's permission before observation.

# %% [markdown]
# ### Studio Class Work

# %% [markdown]
# **Questions**

# %% [markdown]
# ### **Studio Class (SC) 11, Question 8:** <a id="q11h"></a>
#
# Describe in your own words why each principle is important when it comes to conducting research.

# %% [markdown]
# |Number | Principle Name| Answer |
# |---|---|---|
# | 1 | Honesty | Ensuring truthful and accurate data collection is crucial for the survey. Testers must convey findings without distorting facts or omitting essential details, fostering trust within the community. |
# | 2 | Rigour | By attentively avoiding biases, researchers enhance the reliability of their work, resulting in trustworthy and valuable outcomes. |
# | 3 | Transparency| It entails transparently sharing the multiple way of methods, data and results. enabling other researchers to contribute to the research. Transparency also involves prevent potential conflicts of interest, including biases.  |
# | 4 | Fairness | Treat researchers with respect, give them the credit of their works but also try to avoid favoritism  |
# | 5 | Respect | Treating everything that related to the research by considering their emotion and needs. This is to make sure the survey was done responsibly |
# | 6 | Recognition | Respect and recognize the rights, knowledge, and cultural heritage of Aboriginal and Torres Strait Islander people. Engaging with these communities before starting research ensures that their perspectives are included, promoting cultural sensitivity and inclusivity.  |
# | 7 | Accountability |Follow the rules, policies, and guidelines that have been give. As researchers, it's important to be good stewards of public resources, making sure we use them corectly. Thinking about the outcome first before sharing it  |
# | 8 | Promotion |   Cultivate a culture that values ethical conduct. Establishing an atmosphere supportive of responsible research motivates researchers to uphold high standards, thereby contributing to the overall integrity of the research community.  |

# %% [markdown]
# ### **Studio Class (SC) 11, Question 9:** <a id="q11i"></a>
#
# For each stage of the UCD process identify an appropriate research method along with any pitfalls that researchers must be careful about to ensure their work complies with the Principles of responsible research conduct.

# %% [markdown]
# |UCD Stage | Research Method | Description | Pitfall |
# |---|---|---|---|
# | User Data | Quantitive method | Collecting data by using multiple ways of such as demographic, ranking and preference question. The data can be in multiple different type such as preference, number and statistic  | The data provide by the user can be inaccurate and can be easily leak if the privacy between the steps is not secure enough |
# | Pain Points & Goals | Quantitive method | Use to identify user's problem and know what they want to achieve to make a product that can solve their pains point and reach their need   | Bad user pain points and goals could lead to bad personas and create potential problems in the later step  |
# | Personas | Qualitative and Behavioral method | A personas represent a typical user who they are, what can they do. Personas can be later use on create Scenarios & storyboarding  | Bias |
# | Ideations | Quantitive method | Brain storm ideas that can be later use to improve UX | To much Idea can be given at one, lead to overload in the number of feature that will have in the final product. Conflict can also happen between R&D teams  |
# | Scenarios & Storyboarding | Attitudinal and Behavioral method | Create a set base on the personas, how would they interact with the product in their daily life |lack of real life experience which lead to wrong expectation from the develop team  |
# | Prototyping | Qualitative and Behavioral method | To create an unfinished version of the product to gather more data from the end-user and modify it to meet user needs | Create a perfect pixel prototype version will stop the end user to suggest change to the final product |

# %% [markdown]
# ### **Studio Class (SC) 11, Question 10:** <a id="q11j"></a>
#
# Provide an image of the changed parts of your PIF.

# %% [markdown]
# https://rmiteduau-my.sharepoint.com/:w:/r/personal/s4031925_rmit_edu_vn/Documents/Microsoft%20Teams%20Chat%20Files/Example%20PIF%20(participant%20information%20form).docx?d=w053ebca3d5b549c59a543d9abd75fb25&csf=1&web=1&e=WqKAei

# %% [markdown]
# ### **Studio Class (SC) 11, Question 11:** <a id="q11k"></a>
#
# Provide a list of your survey questions.

# %% [markdown]
# *My Answer*

# %% [markdown]
# <style>
# h2 {
#    text-align: center;
# }
# hr {
#   border: none;
#   border-top: 6px ridge #04cfc5;
# }
# </style>
# ___
#
# ## Studio Class 12: Usability Testing
#
# ### Preparation Activities

# %% [markdown]
# **Questions**

# %% [markdown]
# ### **Studio Class (SC) 12, Question 1:** <a id="q12a"></a>
#
# Usability Testing:
#
# Answer the following questions:

# %% [markdown]
# |Question |
# |---|
# | What separates usability testing from other forms of testing? |
# |- You can see the user behaviour instead of asking them directly |
# | Why do you only require a small number of usability testing participants? |
# |- Some or most of the problems will be find after u seen just a couple of participants and it will save a lot of time testing or fixing the issues |
# | What can we use to determine the participants to recruit for a usability test? |
# |- Some of the criteria include Age, gender, experience levels, habits and if they have ever use your product or not|
# | What are the purpose of screener questions? |
# |- To determine if the participant is suitable for the test |

# %% [markdown]
# ### **Studio Class (SC) 12, Question 2:** <a id="q12b"></a>
#
# Planning Usability Testing:
#
# Answer the following questions:

# %% [markdown]
# |Question |
# |---|
# | What is an exploratory task? |
# |- Provide the tester with the result and instead of show them how to do it, we let the tester to find a way to complete the task and find the expected outpu |
# | What is a directed task? |
# |- Give tester a certain task and provide them with a specific feature that will be use to complete and achieve the result |
# | What is an impression task? |
# |- Asking the tester a wide range of question for them to provide their opinions on a certain page |
# | What are the elements contained in a Test Plan? |
# |- Basic info on the participant: <br> + Info on the participant <br> + The tasks <br> + The environment the test will take place in   |
# | Who is the most important person in a usability test? |
# |- The tester is the most important person in a usability test since they are represent the end-user or target audience, Their interactions with the product help contribute to the product improvement |

# %% [markdown]
# ### **Studio Class (SC) 12, Question 3:** <a id="q12c"></a>
#
# Conducting Usability Testing:
#
# Answer the following questions:

# %% [markdown]
# |Question |
# |---|
# | Describe a good approach to being a moderator of a usability test. |
# |- When moderate a usability test u should treat the participation with patient and respectful with the participant, but also u should be confident as a moderator |
# | Describe a good approach to being a observer of a usability test. |
# |- Carefully watch and take notes on what you see, not what you think and do not ask question|

# %% [markdown]
# ### Studio Class Work

# %% [markdown]
# **Questions**

# %% [markdown]
# ### **Studio Class (SC) 12, Question 4:** <a id="q12d"></a>
#
# Provide an image of the changed parts of your PIF.
#
# This is mandatory if this is missing then you will receive zero for this part of the portfolio.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **Studio Class (SC) 12, Question 5:** <a id="q12e"></a>
#
# Your Usability Test Plan:

# %% [markdown]
# |Question |
# |---|
# | Tasks for users to complete: |
# |- Give more option on the Home Page <br> - Login and try to give, the task to other members in the family members <br> - Quick access from the Home Screen to check for the given chores |
# | Screener Questions: |
# |- Are you a parent or child <br> - How many children or siblings that u want to have in the family chore app|
# | Moderator Script: |
# |- Welcome <br> - Show the PIF and ask them to read it and fill it in <br> - Show Home Page <br> - Ask for opinion on home screen <br> - Show login screen <br> - Tell participant to login and find the list of chores, then check on all of them <br> - Show Home Screen with "incomplete" <br> - Ask participant to go directly to incomplete chore from big button|
# | Post Usability Test Survey Questions: |
# |- Rate overall experience of login page <br> - Did the home page inform you of chores accurately <br> - Was the chores list informativ |

# %% [markdown]
# ### **Studio Class (SC) 12, Question 6:** <a id="q12f"></a>
#
# Usability Test Results (Participant 1):
#
# Provide an image of the changed parts of your PIF.
#
# This is mandatory if this is missing then you will receive zero for this part of the portfolio.

# %% [markdown]
# ![Screenshot 2024-01-21 at 00.46.37.png](<attachment:Screenshot 2024-01-21 at 00.46.37.png>)

# %% [markdown]
# ### **Studio Class (SC) 12, Question 7:** <a id="q12g"></a>
#
# Usability Test Results (Participant 1):

# %% [markdown]
# |Question |
# |---|
# | Notes from observers: |
# |-Have difficult identify different feature |
# | Post Usability test survey results: |
# |![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png) |

# %% [markdown]
# ### **Studio Class (SC) 12, Question 8:** <a id="q12h"></a>
#
# Usability Test Results (Participant 2):
#
# Provide an image of the changed parts of your PIF.
#
# This is mandatory if this is missing then you will receive zero for this part of the portfolio.

# %% [markdown]
# *My image*

# %% [markdown]
# ### **Studio Class (SC) 12, Question 9:** <a id="q12i"></a>
#
# Usability Test Results (Participant 2):

# %% [markdown]
# |Question |
# |---|
# | Notes from observers: |
# |Participant tried to return to home screen but couldn't, confused on video call feature |
# | Post Usability test survey results: |
# | ![Screenshot 2024-01-21 at 01.24.18.png](<attachment:Screenshot 2024-01-21 at 01.24.18.png>) ![Screenshot 2024-01-21 at 01.24.43.png](<attachment:Screenshot 2024-01-21 at 01.24.43.png>)|

# %% [markdown]
# ### **Studio Class (SC) 12, Question 10:** <a id="q12j"></a>
#
# Summary of the changes that you propose to your paper prototype as a result of the usability testing:

# %% [markdown]
# *Remove video call, add home button and return button*
