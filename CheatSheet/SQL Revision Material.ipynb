# %%
Standard SQL Query Statement:

SELECT something FROM table WHERE condition;

Statement Format:
 - CAPITALIZED WORDS: Actual SQL Query Syntax
 - lowercase words: User Input

# %%
SELECT: to use for all queries that return values, it is the main way to access the database
FROM: to specify the table to access
WHERE: to specify to the query the condition to filter the table data 
DELETE: to delete rows from a table


Example: 
SELECT column1, column2, ...
FROM table_name
WHERE condition;


OR: to specify an alternative condition to match in the query
AND: to specify an additional condition to match in the query
LIKE: to specify a pattern to match in the query
+ '%' : to match any sequence of characters (including zero characters)
    * ( '%J%' matches any string that contains after a J )
    * ( 'J%' matches any string that starts with a J )
    * ( '%J' matches any string that ends with J )
BETWEEN: to specify a range to match in the query

Example: 
SELECT *
FROM customers
WHERE (first_name LIKE 'J%' OR last_name LIKE '%son')
    AND age >= 30;

Strftime: to specify a date format to match in the query
AS: to specify an alias for a column name in the query
ROUND: to specify the number of decimal places to round to in the query

Example:
SELECT customer_id, first_name, last_name, ROUND(total_amount, 2) AS rounded_amount, Strftime('%Y-%m-%d', order_date) AS formatted_date
FROM orders
WHERE order_status = 'completed';

# %%
Sorting:

To sort a table SQL uses the ORDER BY statement, which is placed at the end of the query statement.

Example:

ORDER BY column_name ASC/DESC;

ORDER BY column1, column2, ... ASC/DESC;

SELECT column1, column2, ... FROM table_name ORDER BY column1, column2, ... ASC/DESC;

ASC: Ascending Order (default)
DESC: Descending Order (reverse)

Example: SELECT * FROM Customers ORDER BY Country;

# %%
Aggregate

- Something formed by adding together several amounts or things
- A whole formed by combining several separate elements

Aggregate Functions:
+ COUNT(): Returns the number of rows that matches a specified criteria
+ SUM(): Returns the total sum of a numeric column
+ AVG(): Returns the average value of a numeric column
+ MIN(): Returns the minimum value of a numeric column
+ MAX(): Returns the maximum value of a numeric column

Example: SELECT COUNT(CustomerID) AS NumberOfCustomers FROM Customers;

# %%
LIMIT: to limit the number of rows returned by the query

OFFSET: to specify the number of rows to skip before starting to return rows from the query

Example: SELECT column1, column2, ... FROM table_name LIMIT number OFFSET offset;

# %%
 - (INNER) JOIN: Returns records that have matching values in both tables
 - LEFT (OUTER) JOIN: Returns all records from the left table, and the matched records from the right table
 - RIGHT (OUTER) JOIN: Returns all records from the right table, and the matched records from the left table
 - FULL (OUTER) JOIN: Returns all records when there is a match in either left or right table

Example: SELECT Orders.OrderID, Customers.CustomerName, Orders.OrderDate

# %% [markdown]
# ![image.png](attachment:image.png)
