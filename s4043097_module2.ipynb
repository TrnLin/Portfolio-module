# %% [markdown]
# <center>
#
# # COSC3056 Programming Studio 1 Portfolio <a id='top'></a>
# # Module 2: Database Storage and Retrieval
#
# </center>

# %% [markdown]
# This portfolio is created by
#
# | Name | *Trần Hoàng Linh* |
# |---|---|
# | Student Id | *S4043097* |
# | Semester | Semester 3 2023 |

# %% [markdown]
# ### Declaration and Statement of Authorship
#
# When you submit your work electronically for studio components, you must agree to the [RMIT assessment declaration](https://www.rmit.edu.au/students/my-course/assessment-results/assessment) below.
#
# 1. I/we have not impersonated, or allowed myself to be impersonated by, any person for the purposes of this assessment.
# 2. This assessment is my/our original work and no part of it has been copied from any other source except where due acknowledgement
# is made.
# 3. No part of this assessment has been written for me/us by any other person except where such collaboration has been authorised
# by the lecturer/teacher concerned.
# 4. Where this work is being submitted for individual assessment, I declare that it is my original work and that no part has been contributed
# by, produced by or in conjunction with another student.
# 5. I/we give permission for my assessment response to be reproduced, communicated compared and archived for the purposes
# of detecting plagiarism.
# 6. I/we give permission for a copy of my assessment to be retained by the university for review and comparison, including review by external examiners.
# 7. I/we understand that:
#     - Plagiarism is the presentation of the work, idea or creation of another person as though it is your own. It is a form of cheating and is a very serious academic offence that may lead to exclusion from the University. Plagiarised material can be drawn from, and presented in, written, graphic and visual form, including electronic data and oral presentations. Plagiarism occurs when the origin of the material used is not appropriately cited.
#     - Plagiarism includes the act of assisting or allowing another person to plagiarise or to copy my work.
#
#
# I/we agree and acknowledge that:
# 1. I/we have read and understood the Declaration and Statement of Authorship above.
# 2. If I/we do not agree to the Declaration and Statement of Authorship in this context and a signature is not included below, the assessment outcome is not valid for assessment purposes and will not be included in my final result for this course.
#
# Visit the student essentials Academic Integrity page for more information on [academic integrity at RMIT](https://www.rmit.edu.au/students/my-course/assessment-results/academic-integrity), including your responsibilities,
# breaches and penalties for academic misconduct.
#
#
# ### Student Signature
# "_I/we declare that I/we have read and understood the above Declaration and Statement of Authorship._"
#
# You must write your full name and student ID in the table in the markdown cell at the top of this portfolio.<br>
# **Failure to do so may result in a grade penalty or a grade of zero.**

# %% [markdown]
# <style>
# blockquote {
#   border: 3px dashed #00DCB4;
#   padding: 10px;
# }
# </style>
#
# > ## Instructions & Information
# > This notebook template has been provided to get you started on your portolfio. It is also structured for the automated marking tool SageGrader.
# > Therefore, we require that you use and edit the notebook correctly.
# >
# > ### How to use this Notebook for your Portfolio
# > To use your notebook, we kindly ask that:
# > 1. Place your answer to the question in the **existing** answer block, by double-clicking on the block you wish to edit.
# > 1. You **must not** delete any existing cells in this notebook and you **must not** modify any existing cell tags. If you accidentally delete a cell, you will need to ``undo'' the change, such using the  "Edit → Undo" VSCode menu option.
# > 1. In general, answer cells will have denoted placeholder content with dummy values, such as comments like *`my answer'*.
# > 1. You **must not** change any text in an existing cell that is **outside** of block to place your answers.
# > 1. To add images to this notebook you **must embedd the image** into the notebook. To do this:
# >     1. Find the image on your computer (Windows: File Explorer, Mac: Finder). Note the image can't have spaces in the filename
# >     1. "Copy" the image (Right-click on the image → Copy)
# >     1. "Paste" the image into the cell below (Double click to edit the cell → Right-click → Paste)
# >     1. If this is done correctly, you should see something of the form ``![image-name.png](attachment:image-name.png)``
# >     1. Please make sure to press the tick '✔️' on the cell containing the image to ensure the attachment is added
# > 1. Please see Canvas for additional assessment instructions.
# >
# > ### How to use Markdown syntax
# > This notebook uses the markdown syntax for formatting. For help on using Markdown, IBM has a good [Markdown Cheat-sheet](https://www.ibm.com/docs/en/watson-studio-local/1.2.3?topic=notebooks-markdown-jupyter-cheatsheet).

# %% [markdown]
# <style>
# h2 {
#    text-align: center;
# }
# hr {
#   border: none;
#   border-top: 6px ridge #b678f4;
# }
# </style>
# ___
#
# ## Studio Class 5: Relational Database Management Systems  <a id="q5"></a>
#
# ### Preparation Activities

# %% [markdown]
# ### **Studio Class (SC) 5, Question 1:** <a id="q5a"></a>
#
# What are the 7 disadvantages of using a spreadsheet to store data?

# %% [markdown]
# | Number | Disadvantages|
# |-------|---------------|
# | 1.    |Time consuming |
# | 2.    |Manual process |
# | 3.    |Unfit for remote working |
# | 4.    |Dependant on one person |
# | 5.    |Lack of collaboration |
# | 6.    |Vulnerable to costly human errors |
# | 7.    |Lack of version control |

# %% [markdown]
# ### **SC 5, Question 2:** <a id="q5b"></a>
#
# What are the properties (or rules) that a Relation in a DBMS must follow?

# %% [markdown]
# *1: Cells contain single values <br> 2: Columns store a single type of information <br> 3: Column names are unique <br> 4: Order is insignificant <br> 5: Rows are unique*

# %% [markdown]
# ### **SC 5, Question 3:** <a id="q5c"></a>
#
# Create a diagram to represent the Database Development Lifecycle.

# %% [markdown]
# *My Answer<br>![Slide 16_9 - 6.png](<attachment:Slide 16_9 - 6.png>)*

# %% [markdown]
# ### **SC 5, Question 4:** <a id="q5d"></a>
#
# How does this Database Development Lifecycle compare to the User-center process?

# %% [markdown]
# *Both have a step where you are going to create a prototype "Conceptual Design" & "Prototyping and building" to test the system, further more while User-center Design is a linear progress DBMS is not a linear progress*

# %% [markdown]
# ### **SC 5, Question 5:** <a id="q5e"></a>
#
# In your own words (not copy-and-paste), describe the purpose of the following values/integrity constraints:

# %% [markdown]
# ### Studio Class Work

# %% [markdown]
# ### **SC 5, Question 6:** <a id="q5f"></a>
#
# How many records are there in each of the tables in the world database?

# %% [markdown]
# | Tables | Records|
# |-------|---------------|
# | City    |*1000* |
# | Country    |*239* |
# | CountryLanguage    |*984* |

# %% [markdown]
# ### **SC 5, Question 7:** <a id="q5g"></a>
#
# Describe the structure of an INSERT statement

# %% [markdown]
# *My Answer "INSERT INTO Customers VALUES (2001, 'Glads Gladdies', 'Childs Road', 'Mill Park', 3082, 500, 0);" <br> <br> INSERT: command promt to add data into the table <br> <br> INTO: where the data gonna go after execute(in this case Customers table) <br> <br> VALUES: the data that will be insert into the table <br> <br> (2001, 'Glads Gladdies', 'Childs Road', 'Mill Park', 3082, 500, 0);: insert data into the right fields*

# %% [markdown]
# ### **SC 5, Question 8:** <a id="q5h"></a>
#
# In Activity 2, Step 4:
# 1. Were you able to enter the third record?
# 1. Should you have been able to enter the third record?
# 1. What type of integrity constraint does the record violate?

# %% [markdown]
# | Questions | Answers|
# |-------|---------------|
# | 1.     |Yes |
# | 2.     |Yes? |
# | 3.     |Entity Intergrity |

# %% [markdown]
# ### **SC 5, Question 9:** <a id="q5i"></a>
#
# In Activity 2, Step 5:
# 1. Were you able to enter the 'Di Hunter' record?
# 1. Are any constraints violated by the 'Di Hunter' record?

# %% [markdown]
# | Questions | Answers|
# |-------|---------------|
# | 1.     |Yes |
# | 2.     |No cause all the missing data have been declare as NULL data |

# %% [markdown]
# ### **SC 5, Question 10:** <a id="q5j"></a>
#
# In Activity 2, Step 5:
# 1. What do the group of 3 records represent in terms of the overall database management system?
# 1. Were you able to enter the records?
# 1. Are any constraints violated by the records?

# %% [markdown]
# | Questions | Answers|
# |-------|---------------|
# | 1.     |Describe where the data is assign to different attribute |
# | 2.     |Yes|
# | 3.     |No, cause all of the value have been assign in to the correct data fields |

# %% [markdown]
# ### **SC 5, Question 11:** <a id="q5k"></a>
#
# Place your answers to Activity 3 questions below.

# %% [markdown]
# The statement doesn't execute, it has violate some constrains which is Entity Integrity and Referential Integrity

# %% [markdown]
# ### **SC 5, Question 12:** <a id="q5l"></a>
#
# Place your answers to Activity 4 questions below.

# %% [markdown]
# 1: Insert <'Robert', 'F', 'Scott', '987654321', '21-JUN-42', '2365 Newcastle Rd, Bellaire, TX', M, 58000, '888665555', 1 > into EMPLOYEE. <br> <br> + 888665555: already exist in EMPLOYEE this could violate Entity Integrity <br> <br> - You can assign the insert with a new id or give the user that the id is already used <br><br> 2: Insert <'ProductA', 3, 'Bellaire', 2> into PROJECT. <br><br> + Pnumber 3 is already exist inside the PROJECT this violate Entity Integrity <br><br> - Notify the user which Pnumber is already used <br> <br>3: Insert <'123454321', null, '40.0'> into WORKS_ON. <br> <br> + 123454321: does not exist in EMPLOYEE this violate Referential Integrity <br> + null might cause error due to it violate Attribute Constraints  <br> <br> - Require the user to check if the id is already used or not <br> - Make the data field feed one type of data and NULL <br> <br> 4: Insert <'453345453', 'John', M, '12-DEC-60', 'SPOUSE'> into DEPENDENT. <br> <br> + 453345453 violate Entity Integrity since it already exist in the EMPLOYEE <br> <br> - You can assign the insert with a new id or give the user that the id is already used <br> <br> 5: Delete the DEPENDENT tuples with dependent_name= 'Joy'. <br> <br> + this statement don't violate with any integrity constraint <br> <br>6: Delete the EMPLOYEE tuple with SSN= '888665555'. <br> <br> + if delete "888665555" it might cause Referential Integrity with the DEPENDENT table <br><br> - if a data was delete in the main data field we should also delete it in other sub data field <br> <br> 7: Update the SUPER_SSN of the EMPLOYEE tuple with SSN='123456789' to '666884444'. <br> <br> +

# %% [markdown]
# ### **SC 5, Question 13:** <a id="q5m"></a>
#
# Your CREATE TABLE statements here from Activity 5.

# %%
PRAGMA foreign_keys = OFF;
drop table if exists company;
drop table if exists product;
drop table if exists stock; 
PRAGMA foreign_keys = ON;

CREATE TABLE COMPANY 
    (   COMPANYID   INTEGER NOT NULL,
        TITLE       VARCHAR(30)     ,
        PRIMARY KEY(COMPANYID)
    )
    WITHOUT ROWID;

CREATE TABLE PRODUCT
    (   PRODUCTID   INTEGER NOT NULL,
        TITLE       VARCHAR(30)     ,
        PRIMARY KEY(PRODUCTID) 
    )
    WITHOUT ROWID;

CREATE TABLE STOCK
    (   COMPANYID     INTEGER NOT NULL,
        PRODUCTID   INTEGER NOT NULL,
        QUANTITY    INTEGER NOT NULL,
        PRIMARY KEY (COMPANYID, PRODUCTID),
        FOREIGN KEY (COMPANYID) REFERENCES COMPANY(COMPANYID),
        FOREIGN KEY (PRODUCTID) REFERENCES PRODUCT(PRODUCTID)
    )
    WITHOUT ROWID;

# %% [markdown]
# <style>
# h2 {
#    text-align: center;
# }
# hr {
#   border: none;
#   border-top: 6px ridge #b678f4;
# }
# </style>
# ___
#
# ## Studio Class 6: Entity Relationship Modelling  <a id="q6"></a>
#
# ### Preparation Activities

# %% [markdown]
# ### **SC 6, Question 1:** <a id="q6a"></a>
#
# Describe in your own words the following concepts:

# %% [markdown]
# | Concepts | Answers|
# |-------|---------------|
# | Strong Entities     |Strong Entities is independent, it not rely on other Entities. Strong Entities have a Primary key that are unique to each occurrence of the entity |
# | Weak Entities     |Weak Entities rely on other type of Entities, they don't have their own Primary key and a weak entities don't have any meaning unless is link with it Strong Entities |

# %% [markdown]
# ### **SC 6, Question 2:** <a id="q6b"></a>
#
# Describe in your own words the following concepts:

# %% [markdown]
# | Concepts | Answers|
# |-------|---------------|
# | Simple Attributes     |It is the smallest kind of attributes that can't not be further divide |
# | Composite Attributes     |It is consist of multiple Attributes  |
# | Multi-valued Attributes     |MA can hold multiples of value for each type of an entity|
# | Relationship Attributes     |Describe the relationship between each Attribute and what happen with them |

# %% [markdown]
# ### **SC 6, Question 3:** <a id="q6c"></a>
#
# Describe in your own words the following concepts:

# %% [markdown]
# | Concepts | Answers|
# |-------|---------------|
# | Cardinality     |The max possible relationship between two attribute |
# | Participation     |Describe which entity is allow to participate in certain entity|

# %% [markdown]
# ### **SC 6, Question 4:** <a id="q6d"></a>
#
# Your ER Diagram for the extending the Company-Department Model

# %% [markdown]
# ![Screenshot 2023-12-21 at 01.19.24.png](<attachment:Screenshot 2023-12-21 at 01.19.24.png>)

# %% [markdown]
# ### **SC 6, Question 5:** <a id="q6e"></a>
#
# Your ER Diagram for the World Database

# %% [markdown]
# ![Screenshot 2023-12-21 at 00.55.28.png](<attachment:Screenshot 2023-12-21 at 00.55.28.png>)

# %% [markdown]
# ## Studio Class Work

# %% [markdown]
# ### **SC 6, Question 6:** <a id="q6f"></a>
#
# Class Activity 1
#
# Learn how to build an Entity-Relationship Model and apply correct cardinality and participation
#
# Insert your ERD for Task 1 (In Class)

# %% [markdown]
# ![Screenshot 2023-12-21 at 12.56.28.png](<attachment:Screenshot 2023-12-21 at 12.56.28.png>)

# %% [markdown]
# ### **SC 6, Question 7:** <a id="q6g"></a>
#
# Class Activity 1
#
# Learn how to build an Entity-Relationship Model and apply correct cardinality and participation
#
# Insert your ERD for Task 3 (Your Own Practice)

# %% [markdown]
# ![Screenshot 2023-12-21 at 13.07.50.png](<attachment:Screenshot 2023-12-21 at 13.07.50.png>)

# %% [markdown]
# ### **SC 6, Question 8:** <a id="q6h"></a>
#
# Class Activity 3
#
# Apply design choices while building an entity-relationship model
#
# Answer the following:

# %% [markdown]
# | Concepts |
# |-------|
# | Identified business rules     |
# | Each bank is uniquely identify by it own number(BankNo), with Name and ABN also include. A bank can have multiple of branch identify by it number (BranchNo), and Address is also given to each branch. <br> <br> A branch maintains many Account, each is assign with it Account Number(AccountNO), and other attribute is include such as Type and Balance. An Account is associated with only one customer, which include Customer Number (CustomerNo) to identify them, Name and Address.<br><br> Customer can get loans from the bank's branch, each loan is identify by it Id (LoanNo), Type and Balance attributes are also include in this entity |
# | Any weak entities     |
# | - Loan is a weak entity <br> - Partial Key: LoanNo <br> - Loan is associated with Customer entity |
# | What contraints are present from any weak entities?     |
# | - LoanNo is not unique identify a loan when it stay alone<br> - Loan need to have relationship with Customer to exist  |
# | List and justify the multiplicities of each relationship.     |
# |+ A Bank can have multiple of branches <br>+ Each branch is associated with a single bank <br><br> + A bank's branch can lends 0 or many     loans <br>+ Each loan is assign to one branch <br> + A branch can have multiple of Accounts <br> + Each Account is associated with only one bank's branch <br> <br> + Customer need to have an account? <br>+ Each account only belong to one customer<br><br>+ Customers can have 0 or many loans <br> + Each loan is associated with one and only one customer |
# | What shortcommings are present in this model?     |
# |- The current model is lacking of many detail about each attributes for each entities, while focusing to much in creating entities and relationships <br> <br>  |
# | How would you change the model to deal with these shortcomings?     |
# |- Give the current entities more attributes to capture more detail  |

# %% [markdown]
# ### **SC 6, Question 9:** <a id="q6i"></a>
#
# Class Activity 3
#
# Apply design choices while building an entity-relationship model
#
# Insert your ERD for Task 3

# %% [markdown]
# ![Screenshot 2023-12-21 at 17.00.09.png](<attachment:Screenshot 2023-12-21 at 17.00.09.png>)

# %% [markdown]
# ### **SC 6, Question 10:** <a id="q6j"></a>
#
# Class Activity 4
#
# Mapping ER model to Relational Database Model
#
# Insert your relational database schemas, including appropriate annotations for primary and foreign keys

# %% [markdown]
# You sent
# Model (<b style="text-decoration: underline;">ModelNo</b>, Capacity, Weight) <br>
# Plane (<b style="text-decoration: underline;">RegNo</b>,ModelNo*) <br>
# Technician (<b style="text-decoration: underline;">SSN</b>, Name, Address, Salary, PhoneNo, ModelNo*, Score*, Hour*, Date*)<br>
# Test (<b style="text-decoration: underline;">CASANo</b>, Name, MaxScore)<br>

# %% [markdown]
# <style>
# h2 {
#    text-align: center;
# }
# hr {
#   border: none;
#   border-top: 6px ridge #b678f4;
# }
# </style>
# ___
#
# ## Studio Class 7: SQL Part I
#
# ### Preparation Activities

# %% [markdown]
# ### **SC 7, Question 1:** <a id="q7a"></a>
#
# Explain the purpose of the named elements a, b & c in the below SQL query.
#
# SELECT &lt;a>
#
# FROM &lt;b>
#
# WHERE &lt;c>
#
# ;

# %% [markdown]
# | Concepts | Answers|
# |-------|---------------|
# | &lt;a>:     |to use for all queries that return value, it is how you gonna get data from the data base |
# | &lt;b>:     |Specify which table to select or delete data from. |
# | &lt;c>:     |Where is use to select which rows to be update or make a change|

# %% [markdown]
# ### **SC 7, Question 2:** <a id="q7b"></a>
#
# Explain how the returned rows of a query can be ordered, and provide an example.

# %% [markdown]
# U can sort the Data table by using "ORDER BY <b>Name</b> DESC/ASC" <br> U can also sort the table by multiple things by using "ORDER BY <b>Name1 , Name2</b> DESC/ASC"  <br><br> Ex: SELECT * FROM Country WHERE Continent = 'Asia' ORDER By GovernmentForm ASC;

# %% [markdown]
# ### **SC 7, Question 3:** <a id="q7c"></a>
#
# Give 3 examples of SQL functions that can be used to aggregate data, and briefly explain what they do.

# %% [markdown]
# | Aggregate function | Explanation|
# |-------|---------------|
# | COUNT()     |use to count the number of values in a specific column|
# | AVG()     |use to calculate the average of all the values in a specific column |
# | SUM()    |use to sum all the values in a specific column|

# %% [markdown]
# ## Studio Class Work

# %% [markdown]
# ### **SC 7, Question 4:** <a id="q7d"></a>
#
# Part A Exercises

# %% [markdown]
# | Question | Explanation|
# |-------|---------------|
# | Question 1:     |SELECT SELECT* FROM MOVIE; |
# | Question 2:     |SELECT MVTitle FROM MOVIE; |
# | Question 3:    |SELECT COUNT(MVTitle) FROM MOVIE; |
# | Question 4:    |SELECT * FROM MOVIE WHERE MvType = 'HORROR' or MvType = 'Horror' or MvType = 'horror'; |
# | Question 5:    |SELECT * FROM MOVIE WHERE (MvType = 'HORROR' or MvType = 'Horror' or MvType = 'horror') AND NOMS > 0;  |
# | Question 6:    |SELECT * FROM MOVIE WHERE ( MvType = 'COMEDY') or (MvType = 'HORROR AND NOMS > 0); |
# | Question 7:    |SELECT MVTitle, NOMS FROM MOVIE WHERE (MvType = 'COMEDY' AND NOMS > 0) or (MvType = 'HORROR' AND NOMS > 0);|
# | Question 8:    |SELECT * FROM MOVIE WHERE AWRD > 3;|
# | Question 9:    |SELECT * FROM MOVIE WHERE MVTitle LIKE '%Nuremberg%'; |

# %% [markdown]
# ### **SC 7, Question 5:** <a id="q7e"></a>
#
# Part B Exercises

# %% [markdown]
# | Question | Explanation|
# |-------|---------------|
# | Question 10:     |SELECT AVG(NUMRENT) FROM MEMBER; |
# | Question 11:     |SELECT MMBNAME, JOINDATE FROM MEMBER; |
# | Question 12:    |SELECT MMBDATE, Strftime('%d/%m/%y', JOINDATE) AS 'JOINDATE' FROM MEMBER; |
# | Question 13:    |SELECT MMBNAME, <br> &nbsp; &nbsp; Strftime('%d/%m/%y', JOINDATE) AS 'JoinDate', <br> &nbsp; &nbsp; (ROUND(Strftime('%J', 'now'))-ROUND(Strftime('%J', JOINDATE))) AS 'num of days', <br> &nbsp; &nbsp; (ROUND(Strftime('%Y', 'now'))-ROUND(Strftime('%Y', JOINDATE))) AS 'num of years', <br> &nbsp; &nbsp; FROM MEMBER;|
# | Question 14:    |SELECT MMBNAME, <br> &nbsp; &nbsp; Strftime('%d/%m/%y', JOINDATE) AS 'JoinDate', <br> &nbsp; &nbsp; (ROUND(Strftime('%J', 'now'))-ROUND(Strftime('%J', JOINDATE))) AS 'num of days', <br> &nbsp; &nbsp; (ROUND(Strftime('%Y', 'now'))-ROUND(Strftime('%Y', JOINDATE))) AS 'num of years', <br> &nbsp; &nbsp; FROM MEMBER ORDER BY MMBNAME; |
# | Question 15:    |SELECT MMBNAME, <br> &nbsp; &nbsp; Strftime('%d/%m/%y', JOINDATE) AS 'JoinDate', <br> &nbsp; &nbsp; (ROUND(Strftime('%J', 'now'))-ROUND(Strftime('%J', JOINDATE))) AS 'num of days', <br> &nbsp; &nbsp; (ROUND(Strftime('%Y', 'now'))-ROUND(Strftime('%Y', JOINDATE))) AS 'num of years', <br> &nbsp; &nbsp; FROM MEMBER ORDER BY ROUND (Strftime ('%J', 'now'))- ROUND (Strftime('%J', JOINDATE)) DESC;|
# | Question 16:    |SELECT MMBNAME, <br> &nbsp; &nbsp; Strftime('%d/%m/%y', JOINDATE) AS 'JoinDate', <br> &nbsp; &nbsp; (ROUND(Strftime('%J', 'now'))-ROUND(Strftime('%J', JOINDATE))) AS 'Number of days since joined', <br> &nbsp; &nbsp; (ROUND(Strftime('%Y', 'now'))-ROUND(Strftime('%Y', JOINDATE))) AS 'Number of years since joined', <br> &nbsp; &nbsp; FROM MEMBER ORDER BY ROUND (Strftime ('%J', 'now'))- ROUND (Strftime('%J', JOINDATE)) DESC;|

# %% [markdown]
# <style>
# h2 {
#    text-align: center;
# }
# hr {
#   border: none;
#   border-top: 6px ridge #b678f4;
# }
# </style>
# ___
#
# ## Studio Class 8: SQL Part II
#
# ### Preparation Activities

# %% [markdown]
# ### **SC 8, Question 1:** <a id="q8a"></a>
#
# Explain what the SQL JOIN operator does.

# %% [markdown]
# Join is use to Queries on related data from multiple table

# %% [markdown]
# ### **SC 8, Question 2:** <a id="q8b"></a>
#
# Describe the difference(s) between an INNER JOIN, LEFT JOIN and RIGHT JOIN.
#
# You should provide your own diagram(s) as part of your explanation.

# %% [markdown]
# | Name | Explanation|
# |-------|---------------|
# | INNER JOIN     |It the default JOIN when you use join statement, it include rows from both table |
# | LEFT JOIN     |it include rows from both table, plus all the table on the left where the condition is not meet |
# | RIGHT JOIN     |it include rows from both table, plus all the table on the left where the condition is not meet, but this is consider as a special case|

# %% [markdown]
# ## Studio Class Work

# %% [markdown]
# ### **SC 8, Question 3:** <a id="q8c"></a>
#
# Part A Exercises

# %% [markdown]
# | Question | Explanation|
# |-------|---------------|
# | Question 1:     |SELECT Movie.MvTitle, Director.DirName <br> FROM Movie JOIN Director ON Movie.DirNumb = Director.DirNumb;|
# | Question 2:     |SELECT * FROM Movie NATURAL JOIN Director; |
# | Question 3:    | SELECT m.MvTitle FROM Movie AS m <br> JOIN Director AS d <br> ON m.DirNumb = d.DirNumb WHERE LOWER( d.DirName ) = 'allen, woody';|
# | Question 4:    |SELECT Movie.MvTitle, Director.DirName <br> FROM Movie JOIN Director ON Movie.DirNumb = Director.DirNumb <br>WHERE Director.DirDied IS NOT NULL;|
# | Question 5:    |SELECT s.STARNAME FROM <br> (MOVIE AS m JOIN MOVSTAR AS ms ON m.MVNUMB = ms.MVNUMB)<br> JOIN Star AS s ON s.STARNUMB = ms.MVNUMB WHERE LOWER (m.MVTITLE) = 'manhattan'; |
# | Question 6:    |SELECT m.MVTITLE, d.DirName, s.StarName  <br> FROM ((Movie AS m JOIN MOVSTAR AS ms ON M.MVNUMB = ms.MVNUMB)<br>JOIN STAR AS s ON s.STARNUMB = ms.STARNUMB)  <br>JOIN DIRECTOR AS d ON m.DIRNUMB <br>WHERE LOWER (s.STARNAME) = LOWER (d.DIRNAME);|
# | Question 7:    |SELECT d.DIRNAME, m.MVTITLE FROM DIRECTOR AS d <br> LEFT JOIN MOVIE AS m  <br> ON d.DIRNUMB = m.DIRNUMB;  |
# | Question 8:    |SELECT s2.STARNAME <br > FROM (STAR AS s1 JOIN MOVSTAR AS ms1 ON s1.STARNUMB = ms1.STARNUMB)<br> JOIN Movie M1 ON MS1.MvNumb = M1.MvNumb <br> JOIN MovStar MS2 ON M1.MvNumb = MS2.MvNumb<br> JOIN Star S2 ON MS2.StarNumb = S2.StarNumb <br> WHERE s1.STARNAME LIKE '%allen%' AND S2.STARNAME NOT LIKE '%allen%'; |

# %% [markdown]
# ### **SC 8, Question 4:** <a id="q8d"></a>
#
# Part B Exercises

# %% [markdown]
# | Question | Explanation|
# |-------|---------------|
# | Question 9:     |SELECT DISTINCT s.STARNAME <br>FROM STAR s NATURAL JOIN MOVSTAR ms <br> WHERE ms.MVNUMB IN(SELECT ms1.MVNUMB <br> FROM STAR s1 NATURAL JOIN MOVSTAR ms1 <br> WHERE LOWER (s1.STARNAME) LIKE '%aline%') <br>  AND LOWER(s.STARNAME) <> 'allen, woody'|
# | Question 10:     |SELECT DISTINCT s.STARNAME FROM STAR s JOIN MOVSTAR ms ON s.STARID = ms.STARID WHERE EXISTS ( SELECT 1 FROM STAR s1 JOIN MOVSTAR ms1 ON s1.STARID = ms1.STARID WHERE LOWER(s1.STARNAME) LIKE '%aline%' AND ms.MVNUMB = ms1.MVNUMB ) AND LOWER(s.STARNAME) <> 'allen, woody';|
# | Question 11:    |SELECT TITLE FROM MOVIE <br> WHERE YRMDE = (SELECT MAX(YRMDE) FROM MOVIE); |
# | Question 12:    |SELECT MVTITLE FROM DIRECTOR d NATURAL JOIN MOVIE m <br> WHERE LOWER(d.DIRNAME) LIKE '%alfred%' AND m.MVNUMB NOT IN <br> (SELECT MVNUMB FROM BORROW b NATURAL JOIN MEMBER MM <br>  WHERE LOWER (mm.MMBNAME) LIKE '%thanh%');  |
# | Question 13:    |SELECT m.MVTITLE <br> FROM DIRECTOR d NATURAL JOIN MOVIE m <br> WHERE NOT EXIST (<br> SELECT * FROM BORROW b NATURAL JOIN MEMBER mm <br> WHERE LOWER (mm.MMBNAME) LIKE '%thanh%' AND m.MVNUMB =b.MVNUMB) <br> AND LOWER(d.DIRNAME) LIKE '%alfred%' |
# | Question 14:    |SELECT m.MVTITLE FROM MOVIE WHERE MVNUMB = ( SELECT MVNUMB FROM MOVSTAR WHERE STARID = ( SELECT STARID FROM STAR WHERE LOWER(STARNAME) LIKE '%hitchcock%' ) GROUP BY MVNUMB ORDER BY COUNT(*) DESC LIMIT 1 );|
